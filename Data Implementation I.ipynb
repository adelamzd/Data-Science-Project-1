# %%
import pandas as pd

# %%
data = pd.read_csv("/content/student-math.csv")

# %%
data
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %% [markdown]
# #Soal 1

# %%
murid_gp = data[data['school']=='GP']

# %%
murid_gp
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4  at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1  at_home     other
# 2       GP   F   15       U     LE3       T     1     1  at_home     other
# 3       GP   F   15       U     GT3       T     4     2   health  services
# 4       GP   F   16       U     GT3       T     3     3    other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...      ...       ...
# 344     GP   F   18       U     GT3       T     2     3  at_home     other
# 345     GP   F   18       U     GT3       T     3     2    other  services
# 346     GP   M   18       R     GT3       T     4     3  teacher  services
# 347     GP   M   18       U     GT3       T     4     3  teacher     other
# 348     GP   F   17       U     GT3       T     4     3   health     other
#
# ...

# %%
murid_gp['G3'].mean()
# Out:
# 10.489971346704872

# %% [markdown]
# #Soal 2

# %%
murid_ms = data[data['school']=='MS']

# %%
murid_ms
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 349     MS   M   18       R     GT3       T     3     2     other     other
# 350     MS   M   19       R     GT3       T     1     1     other  services
# 351     MS   M   17       U     GT3       T     3     3    health     other
# 352     MS   M   18       U     LE3       T     1     3   at_home  services
# 353     MS   M   19       R     GT3       T     1     1     other     other
# 354     MS   M   17       R     GT3       T     4     3  services     other
# 355     MS   F   18       U     GT3       T     3     3  services  services
# 356     MS   F   17       R     GT3       T     4     4   teacher  services
# 357     MS   F   17       U     LE3       A     3     2  services     other
# 358     MS   M   18       U     LE3       T     1     1     other  services
# 359     MS   F   18       U     LE3       T     1     1   at_home  services
# ...

# %%
print(murid_ms['G3'].min())
print(murid_ms['G3'].max())
# Out:
# 0
# 19

# %% [markdown]
# #Soal 3

# %%
data['sex'].value_counts() / len(data)
# Out:
# F    0.526582
# M    0.473418
# Name: sex, dtype: float64

# %%
(data['sex'].value_counts() / len(data)) * 100
# Out:
# F    52.658228
# M    47.341772
# Name: sex, dtype: float64

# %% [markdown]
# #Soal 4

# %%
data.groupby('studytime')['G3'].mean()
# Out:
# studytime
# 1    10.047619
# 2    10.171717
# 3    11.400000
# 4    11.259259
# Name: G3, dtype: float64

# %% [markdown]
# #Soal 5

# %%
data.groupby('schoolsup')['G3'].mean()
# Out:
# schoolsup
# no     10.561047
# yes     9.431373
# Name: G3, dtype: float64
